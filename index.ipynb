# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
# extract packages

import pandas as pd
pd.options.display.max_rows = 999
from bs4 import BeautifulSoup
import requests
import re

# %%
# request page and soupify

url ='https://www.residentadvisor.net/events/uk/london/week/2020-06-15'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser' )
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in London, United Kingdom
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, london, united, kingdom" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=FkfRVAlFvpndxqgZliJaJOXD-OhkiRFP8nrBK9Pg2R01" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/uk/london").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "UK").setTargeting("Area", "London"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?637253939250654321"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mStreamland"><a ga-event-action="Streamland" ga-event-category="nav" ga-on="click" href="/events/streamland">
# Streamland</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2020/5">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./2020-06-15?cc=uk&amp;an=london&amp;v=week&amp;mn=06&amp;yr=2020&amp;dy=15" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="XMM1c4rZMNl8RBt9Hk/zUKNRHj5ICxztOpoDqz05AZjeb9H3IY8Sp6ctQGnpBSu6KmJLq56L6DN1lKC4f6MpaSqTeBU="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-08">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-22">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="3"/>
# <span>UK</span><input id="country-name" type="hidden" value="United Kingdom"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events/uk/london/week/2020-06-15">Canada</a></li><li data-id="15"><a href="/events/uk/london/week/2020-06-15">France</a></li><li data-id="12"><a href="/events/uk/london/week/2020-06-15">Germany</a></li><li data-id="20"><a href="/events/uk/london/week/2020-06-15">Italy</a></li><li data-id="6"><a href="/events/uk/london/week/2020-06-15">Netherlands</a></li><li data-id="5"><a href="/events/uk/london/week/2020-06-15">Spain</a></li><li class="selected" data-id="3"><a href="/events/uk/london/week/2020-06-15">United Kingdom</a></li><li data-id="2"><a href="/events/uk/london/week/2020-06-15">United States of America</a></li><li data-id="0"><a href="/events/uk/london/week/2020-06-15">------------</a></li><li data-
span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-06-16T00:00" itemprop="startDate">2020-06-16T00:00</time></span><a href="/events/1343621"><img height="76" src="/images/events/flyer/2020/6/uk-0612-1343621-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1343621" itemprop="url" title="Event details of Grace Jones' Meltdown festival">Grace Jones' Meltdown festival</a> <span>at <a href="/club.aspx?id=19738">Southbank Centre</a></span></h1><div class="grey event-lineup">Grace Jones, Solange, Peaches, Jimmy Cliff, The Love Unlimited Synth Orchestra, Skunk Anansie, Baaba Maal, Lee 'Scratch' Perry with Adrian Sherwood, Oumou Sangaré, Meshell Ndegeocello, Lee Fields &amp; The Expressions, Ladysmith Black Mambazo</div><p class="attending"><span>30</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=13&amp;v=day&amp;mn=6&amp;yr=2020&amp;dy=17"><span>Wed, 17 Jun 2020 /</span></a></p></li><li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1304245#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2020-06-17T00:00" itemprop="startDate">2020-06-17T00:00</time></span><a href="/events/1304245"><img height="76" src="/images/listing-default.gif" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1304245" itemprop="url" title="Event details of Art of Noise Reboot">Art of Noise Reboot</a> <span>at <a href="/club.aspx?id=1502">The Jazz Cafe</a></span></h1><div ...
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option value="7">July</option>
# <option selected="selected" value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option value="2021">2021</option>
# <option selected="selected" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="15"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/uk/london/week/2020-05-31">31</a></td><td><a href="/events/uk/london/week/2020-06-01">1</a></td><td><a href="/events/uk/london/week/2020-06-02">2</a></td><td><a href="/events/uk/london/week/2020-06-03">3</a></td><td><a href="/events/uk/london/week/2020-06-04">4</a></td><td><a href="/events/uk/london/week/2020-06-05">5</a></td><td><a href="/events/uk/london/week/2020-06-06">6</a></td></tr><tr><td><a href="/events/uk/london/week/2020-06-07">7</a></td><td><a href="/events/uk/london/week/2020-06-08">8</a></td><td><a href="/events/uk/london/week/2020-06-09">9</a></td><td><a href="/events/uk/london/week/2020-06-10">10</a></td><td><a href="/events/uk/london/week/2020-06-11">11</a></td><td><a href="/events/uk/london/week/2020-06-12">12</a></td><td><a href="/events/uk/london/week/2020-06-13">13</a></td></tr><tr><td><a href="/events/uk/london/week/2020-06-14">14</a></td><td><span class="day-current">15</span></td><td><a href="/events/uk/london/week/2020-06-16">16</a></td><td><a href="/events/uk/london/week/2020-06-17">17</a></td><td><a href="/events/uk/london/week/2020-06-18">18</a></td><td><a href="/events/uk/london/week/2020-06-19">19</a></td><td><a href="/events/uk/london/week/2020-06-20">20</a></td></tr><tr><td><a href="/events/uk/london/week/2020-06-21">21</a></td><td><a href="/events/uk/london/week/2020-06-22">22</a></td><td><a href="/events/uk/london/week/2020-06-23">23</a></td><td><a href="/events/uk/london/week/2020-06-24">24</a></td><td><a href="/events/uk/london/week/2020-06-25">25</a></td><td><a href="/events/uk/london/week/2020-06-26">26</a></td><td><a href="/events/uk/london/week/2020-06-27">27</a></td></tr><tr><td><a href="/events/uk/london/week/2020-06-28">28</a></td><td><a href="/events/uk/london/week/2020-06-29">29</a></td><td><a href="/events/uk/london/week/2020-06-30">30</a></td><td><a class="day-off" href="/events/uk/london/week/2020-07-01">1</a></td><td><a class="day-off" href="/events/uk/london/week/2020-07-02">2</a></td><td><a class="day-off" href="/events/uk/london/week/2020-07-03">3</a></td><td><a class="day-off" href="/events/uk/london/week/2020-07-04">4</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text();
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area.replace(/[^A-Z0-9À-ž]/ig, '').toLowerCase().normalize("NFD").replace(/[\u0300-\u036f]/g, "") + "/"
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top London clubs</h1>
# <ul>
# <li><a ga-event-action="fabric" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=237">fabric</a> /</li><li><a ga-event-action="Studio 338" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=74592">Studio 338</a> /</li><li><a ga-event-action="Printworks" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=127337">Printworks</a> /</li><li><a ga-event-action="Egg London" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=874">Egg London</a> /</li><li><a ga-event-action="Corsica Studios" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2587">Corsica Studios</a> /</li><li><a ga-event-action="XOYO" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=33592">XOYO</a> /</li><li><a ga-event-action="Ministry Of Sound" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=725">Ministry Of Sound</a> /</li><li><a ga-event-action="Village Underground" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=4567">Village Underground</a> /</li><li><a ga-event-action="Tobacco Dock" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=83715">Tobacco Dock</a> /</li><li><a ga-event-action="E1 London" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=141756">E1 London</a> /</li><li><a ga-event-action="Oval Space" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=60356">Oval Space</a> /</li><li><a ga-event-action="Lightbox" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=13311">Lightbox</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=13">More London clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/streamland">Streamland</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Midlands" ga-event-category="top-regions" ga-on="click" href="/guide/uk/midlands">Midlands, UK</a> /</li><li><a ga-event-action="Other regions" ga-event-category="top-regions" ga-on="click" href="/guide/nl/otherregions">Other regions, NL</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/croatia">Croatia</a> /</li><li><a ga-event-action="Detroit" ga-event-category="top-regions" ga-on="click" href="/guide/us/detroit">Detroit, US</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/belgium">Belgium</a> /</li><li><a ga-event-action="South" ga-event-category="top-regions" ga-on="click" href="/guide/es/south">South, ES</a> /</li><li><a ga-event-action="North" ga-event-category="top-regions" ga-on="click" href="/guide/uk/north">North, UK</a> /</li><li><a ga-event-action="Leeds" ga-event-category="top-regions" ga-on="click" href="/guide/uk/leeds">Leeds, UK</a> /</li><li><a ga-event-action="Prague" ga-event-category="top-regions" ga-on="click" href="/guide/cz/prague">Prague, CZ</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-08">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-22">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 15 May 2020</p>
# <a href="/news/72186">
# <img class="thumb" src="/images/news/2020/berlin-clubs-reopening.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72186/?comments=1">Post a comment</a>
# </p><a href="/news/72186">
# <h1>Coronavirus latest: Berlin clubs reopening as beer gardens, Taipei club Pawnshop to reopen</h1>
# </a>
# <p class="copy">Everything we know about how COVID-19 (the disease caused by the novel coronavirus) is affecting the electronic music scene.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 16 May 2020</p>
# <a href="/news/72673">
# <img class="thumb" src="/images/news/2020/berlin-clubs-reopening.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72673/?comments=1">Post a comment</a>
# </p><a href="/news/72673">
# <h1>Some Berlin clubs to reopen as afternoon beer gardens with no-dancing rules</h1>
# </a>
# <p class="copy">Sisyphos is one of the venues that will operate with a food license from this weekend.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 11 May 2020</p>
# <a href="/news/72634">
# <img class="thumb" src="/images/news/2020/pascal-feos-dies.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72634/?comments=1">Post a comment</a>
# </p><a href="/news/72634">
# <h1>Frankfurt techno originator Pascal F.E.O.S. has died aged 52</h1>
# </a>
# <p class="copy">He was known for his work in groups like Resistance and had a number of other aliases.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72651">
# <img class="thumb" src="/images/news/2020/boomtown-independent-uk-festivals-collapse-aif.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72651/?comments=1">Post a comment</a>
# </p><a href="/news/72651">
# <h1>Independent UK festivals on brink of 'collapse' from coronavirus pandemic</h1>
# </a>
# <p class="copy">92 percent of Association Of Independent Festivals members report their events businesses will likely not survive without sufficient government relief.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 16 May 2020</p>
# <a href="/news/72671">
# <img class="thumb" src="/images/news/2020/jamie-xx-avalanches-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72671/?comments=1">Post a comment</a>
# </p><a href="/news/72671">
# <h1>Mix Of The Day: Jamie xx &amp; The Avalanches</h1>
# </a>
# <p class="copy">The feel good back-to-back of the summer.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 14 May 2020</p>
# <a href="/news/72658">
# <img class="thumb" src="/images/news/2020/lift-the-siege-eno-massive-attack.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72658/?comments=1">Post a comment</a>
# </p><a href="/news/72658">
# <h1>Brian Eno and Massive Attack join calls for an end to Israel's blockade on Gaza amid the pandemic</h1>
# </a>
# <p class="copy">Helm, Hiro Kone and Violet were among a group of artists urging Israel to lift its blockade.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72652">
# <img class="thumb" src="/images/news/2020/apple-logic-pro.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72652/?comments=1">Post a comment</a>
# </p><a href="/news/72652">
# <h1>Apple reveals major update to Logic Pro X</h1>
# </a>
# <p class="copy">Logic Pro X 10.5 is the most substantial update since Logic Pro X's launch in 2013.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 May 2020</p>
# <a href="/news/72619">
# <img class="thumb" src="/images/news/2020/sonar-2020-postponed.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72619/?comments=1">Post a comment</a>
# </p><a href="/news/72619">
# <h1>Barcelona's Sónar and OFFSónar postponed until 2021</h1>
# </a>
# <p class="copy">They'll try to retain as many 2020 artists as possible for next year's edition.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 15 May 2020</p>
# <a href="/news/72664">
# <img class="thumb" src="/images/news/2020/hunee-mix-of-the-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72664/?comments=1">Post a comment</a>
# </p><a href="/news/72664">
# <h1>Mix Of The Day: Hunee</h1>
# </a>
# <p class="copy">A mix of classical, ambient and jazz from the master selector.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 14 May 2020</p>
# <a href="/news/72662">
# <img class="thumb" src="/images/news/2020/thebookofdrexciya.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72662/?comments=1">Post a comment</a>
# </p><a href="/news/72662">
# <h1>Tresor to release Drexciya graphic novel</h1>
# </a>
# <p class="copy">The Book Of Drexciya, Vol. 1. is out next week.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72626">
# <img class="thumb" src="/images/news/2020/all-club-shanghai-coronavirus-fundraising-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72626/?comments=1">Post a comment</a>
# </p><a href="/news/72626">
# <h1>Shanghai club ALL launches fundraiser to prevent closure</h1>
# </a>
# <p class="copy">"All proceeds from sales will go towards digging us out of a hole," said the venue's founder Gaz Williams, who also runs SVBKVLT.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 May 2020</p>
# <a href="/news/72630">
# <img class="thumb" src="/images/news/2020/moog-subharmonicon-studio-suzanne-ciani-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72630/?comments=1">Post a comment</a>
# </p><a href="/news/72630">
# <h1>Suzanne Ciani tries out Moog's new analogue synthesizer, The Subharmonicon, on film score</h1>
# </a>
# <p class="copy">The synth pioneer has scored a short film, Music As Living Matter, with the new instrument.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72636">
# <img class="thumb" src="/images/news/2020/zenker-brothers-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72636/?comments=1">Post a comment</a>
# </p><a href="/news/72636">
# <h1>Mix Of The Day: Zenker Brothers</h1>
# </a>
# <p class="copy">The first live recording in a new series from Ilian Tape and London venue FOLD.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 11 May 2020</p>
# <a href="/news/72631">
# <img class="thumb" src="/images/news/2020/ty-main.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72631/?comments=1">Post a comment</a>
# </p><a href="/news/72631">
# <h1>UK hip-hop pioneer Ty dies of COVID-19 complications aged 47</h1>
# </a>
# <p class="copy">The revered UK rapper passed away on Thursday after contracting pneumonia related to the novel coronavirus.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 15 May 2020</p>
# <a href="/news/72663">
# <img class="thumb" src="/images/news/2020/friday-bandcamp-06.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72663/?comments=1">Post a comment</a>
# </p><a href="/news/72663">
# <h1>Friday Bandcamp Roundup: May 15th</h1>
# </a>
# <p class="copy">A look into this week's Bandcamp offerings, including records from Fire-Toolz, Schacke and Pacific Coliseum.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 15 May 2020</p>
# <a href="/news/72667">
# <img class="thumb" src="/images/news/2020/ellen-allien-new-album-auraa-true-romantics-erased-memories-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72667/?comments=1">Post a comment</a>
# </p><a href="/news/72667">
# <h1>Ellen Allien announces new album, Auraa</h1>
# </a>
# <p class="copy">The seven-track LP is out on BPitch Control June 12th, with the True Romantics single out now.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72645">
# <img class="thumb" src="/images/news/2020/wuttke-roman-flugel-primitive-painter-acid-jesus.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72645/?comments=1">Post a comment</a>
# </p><a href="/news/72645">
# <h1>Apollo unearths 'lost classic' album from Roman Flügel and Jörn Elling Wuttke</h1>
# </a>
# <p class="copy">The Primitive Painter's 1994 album, which mixes IDM and ambient house, has gone on to command high prices on the secondhand market.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 12 May 2020</p>
# <a href="/news/72635">
# <img class="thumb" src="/images/news/2020/finn-motd-2020-mixtape.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72635/?comments=1">Post a comment</a>
# </p><a href="/news/72635">
# <h1>Mix Of The Day: Finn</h1>
# </a>
# <p class="copy">The UK producer has shared an hour-long mixtape of music he'll release through the year.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 13 May 2020</p>
# <a href="/news/72647">
# <img class="thumb" src="/images/news/2020/mr-beatnick-mythstery.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72647/?comments=1">Post a comment</a>
# </p><a href="/news/72647">
# <h1>Mr Beatnick returns with new album, Honeycomb</h1>
# </a>
# <p class="copy">The new record—the London-based house head's first LP since 2013—is out on Mythstery Records on June 12th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 14 May 2020</p>
# <a href="/news/72659">
# <img class="thumb" src="/images/news/2020/dj-boring-press-pic-may.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72659/?comments=1">Post a comment</a>
# </p><a href="/news/72659">
# <h1>DJ BORING announces first single in two years</h1>
# </a>
# <p class="copy">Like Water is the lo-fi house producer's debut on Ninja Tune's Technicolour imprint.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2020 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><a ga-event-action="store" ga-event-category="homefooter" ga-on="click" href="https://store.ra.co">RA Store</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
# construct a container
container = soup.find(id = 'items')

# %%
# this is each row within the container, some may contain dates, some may contain event data
rows = container.findAll('li')
len(rows)
# Out:
# 39

# %%
# find rows that have the date and rows that do not.
a = rows[3].find(class_ = 'eventDate date') # note this returns None
b = rows[2].find(class_ = 'eventDate date') # this will return a <p> tag with the date
print(a, b)

# using the result below, build a condition whereby if the result is None populate a list with NA else parse the tag
# and return the date
type(b)
# Out:
# None <p class="eventDate date"><a href="/events.aspx?ai=13&amp;v=day&amp;mn=6&amp;yr=2020&amp;dy=16"><span>Tue, 16 Jun 2020 /</span></a></p>
# bs4.element.Tag

# %%
# traverse the container; searching by h1 heading should narrow things down
eventdata = container.findAll('h1', class_ ='event-title')
len(eventdata)
# Out:
# 30

# %%
# looks like extracting the text behind the a tag might extract just the event name (this should be Event_Name)
name = eventdata[0].find('a').text

# write a loop that iterates through the container for a list of names that will be used in the dataframe (final_name_list)
final_name_list = [ ]

#set up a list that contains the list of names
#this list will be used by the for loop to populate the final_name_list 
#ONLY where an event-title exists.
name_list = [ ]

# this loop is used to populate a list of event names for use in name_list
for n in range(len(eventdata)):
    name = eventdata[n].find('a').text
    name_list.append(name)

# this loop is used to check if there is an event name in a row, if not, return NaN
# if there is an event name, it takes the actual name of the event from name_list and uses it to populate final_name_list
# final_name_list goes into final dataframe

name_list_counter = 0

for n in range(len(rows)):
    
    if rows[n].find(class_ = 'event-title') == None:
        final_name_list.append('NaN')
    else:
        final_name_list.append(name_list[name_list_counter])
        name_list_counter += 1

    
print(final_name_list, len(final_name_list))
# Out:
# ['NaN', "Grace Jones' Meltdown festival", 'NaN', 'Art of Noise Reboot', "Grace Jones' Meltdown festival", 'NaN', 'Art of Noise Reboot', "Grace Jones' Meltdown festival", '[CANCELLED] VØID: Venetian Snares & Big Lad vs Sly & The Family Drone', 'NaN', 'Art of Noise Reboot', 'Throwback Thursdays at PI // Student Drink Deals', 'NaN', '[RESCHEDULED] The Pickle Factory with Prosumer & Tama Sumo All Night Long', 'Chancha Via Circuito', 'Session Victim: Every Friday in June', 'Fabio (Jungle Set) ft Jumping Jack Frost B2B Bryan Gee, DJ Ron, DJ Rap & Ragga Twins', 'Gold Teeth', 'Antics', 'Supa Dupa Fly x Trapeze Basement', '[CANCELLED] Palms Trax b2b Young Marco & Kamma & Masalo', 'NaN', 'NaN', 'Sankeys London Beach Rave', "Byday Bynight - June's Summer Rooftop Party Brixton", 'Chancha Via Circuito', 'Garagebox: 2020 Opening Party', '[RESCHEDULED] Footwrk 005: Cosmic Disco with Pete Herbert', 'UKG Brunch', 'London Boat Party with Free After Party', 'Shut The Front Door: Summer Solstice Day & Night Terrace Party', 'sub:Terra', 'Clockwork Orange Clockstock 2020', 'One Out Festival', 'Foreverland Festival ∙ The Fantasy Fairground', 'The Get Up: TBC', 'NaN', 'NaN', 'Foreverland Festival ∙ The Fantasy Fairground'] 39

# %%
eventdata[0]
# Out:
# <h1 class="event-title" itemprop="summary"><a href="/events/1343621" itemprop="url" title="Event details of Grace Jones' Meltdown festival">Grace Jones' Meltdown festival</a> <span>at <a href="/club.aspx?id=19738">Southbank Centre</a></span></h1>

# %%
# extract just the venue
# defining the venue with reference to the event helps to link the event and the venue

venue = eventdata[0].find('span').text.strip('at ')
venue

# set up a list of venues actually found in the container that will be used to populate final_venue_list
venue_list = [ ]

# set up an empty list of final_venue_list which will be used to construct the dataframe
final_venue_list = [ ]

# this loop is used to populate the event names actually found in the container that will, in turn, be used to
# populate the final_venue_list
for v in range(len(eventdata)):
    venue = eventdata[v].find('span').text.strip('at ')
    venue_list.append(venue)

# this loop is used to populate the final_venue_list used in the dataframe, it will search each row of the container
# where it does not find a venue name in a row, it will return NaN and populate final_venue_list accordingly
# where it does find a venue name, it will take a name from the venue_list and populate final_venue_list accordingly.

venue_list_counter = 0

for v in range(len(rows)):
    
    if rows[v].find(class_ = 'event-title') == None:
        final_venue_list.append('NaN')
    else:
        final_venue_list.append(venue_list[venue_list_counter])
        venue_list_counter += 1
    
print(final_venue_list, len(final_venue_list))
# Out:
# ['NaN', 'Southbank Centre', 'NaN', 'The Jazz Cafe', 'Southbank Centre', 'NaN', 'The Jazz Cafe', 'Southbank Centre', 'fabric', 'NaN', 'The Jazz Cafe', 'Piccadilly Institute', 'NaN', 'The Pickle Factory', 'The Jazz Cafe', 'The Jazz Cafe', 'Camden Assembly', 'Brixton Jamm', 'Fest Camden', 'Trapeze Basemen', 'XOYO', 'NaN', 'NaN', 'Studio 338', 'The Prince of Wales', 'The Jazz Cafe', 'TBA - London', 'Simulacra Studio', 'TBA - London', 'Crown Pier', 'Brixton Jamm', 'Forest Road Brewery', 'Chelmsford City Racecourse', 'Apps Court Farm, Surrey', 'Dreamland Margate', 'Fire & Lightbox', 'NaN', 'NaN', 'Dreamland Margate'] 39

# %%
# extract just the date
date = container.findAll('p', class_ = 'eventDate date')
date[5].find('a').text.strip(' /')

# write a loop that iterates through the container for the date of the event to generate a list
# NOTE: certain dates have more events than others
final_date_list = [ ]

for d in range(len(rows)):
    if rows[d].find(class_ = 'eventDate date') == None:
        final_date_list.append(date)
    else:
        date = rows[d].find('a').text.strip(' /')
        final_date_list.append(date)
    
print(final_date_list, len(final_date_list))
# Out:
# ['Mon, 15 Jun 2020', 'Mon, 15 Jun 2020', 'Tue, 16 Jun 2020', 'Tue, 16 Jun 2020', 'Tue, 16 Jun 2020', 'Wed, 17 Jun 2020', 'Wed, 17 Jun 2020', 'Wed, 17 Jun 2020', 'Wed, 17 Jun 2020', 'Thu, 18 Jun 2020', 'Thu, 18 Jun 2020', 'Thu, 18 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Fri, 19 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sat, 20 Jun 2020', 'Sun, 21 Jun 2020', 'Sun, 21 Jun 2020'] 39

# %%
# get the number of attendees turn it so that it returns an integer
# NOTE: not every event will have attendees
attend = container.findAll('p', class_ = 'attending')
int(attend[17].text.strip('Attending '))

#set up an empty list, populating with number of attendees specified by the page.
attend_list = [ ]

#set up a final_attend_list to be used to construct the dataframe, this is populated with
#the figures from attend_list where available and populated with NaN if not available.
final_attend_list = [ ]

# this loop populates attend_list and creates a list of number of attendees where they have been specified
for a in range(len(attend)):
        a_num = int(attend[a].text.strip('Attending '))
        attend_list.append(a_num)

# this loop populates the final_attend_list such with numbers from attend_list where available, otherwise for listings
# that do not specify any number of attendees, NaN is returned.

attend_list_counter = 0

for a in range(len(rows)):
    if rows[a].find(class_ = 'attending') == None:
        final_attend_list.append(0)
    else:
        final_attend_list.append(attend_list[attend_list_counter])
        attend_list_counter +=1
        
print(final_attend_list, len(final_attend_list))
# Out:
# [0, 30, 0, 7, 30, 0, 7, 30, 24, 0, 1, 0, 0, 75, 13, 13, 2, 1, 1, 1, 63, 0, 0, 199, 63, 13, 7, 6, 2, 2, 1, 0, 21, 0, 0, 0, 0, 0, 4] 39

# %%
type(attend_list[1])
# Out:
# int

# %%
# put all the lists together and return the length of each list just to ensure they are the same length
final_lists = [final_name_list, final_venue_list, final_date_list, final_attend_list]
y = [len(x) for x in final_lists]
y
# Out:
# [39, 39, 39, 39]

# %%
# construct the dataframe
df = pd.DataFrame(final_lists).transpose()
df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]

#columns where the Event Name is NaN can be removed.
df = df.loc[df['Event_Name'] != 'NaN']

# this resets the index and drops the old index which doesn't work anymore now that the NaNs have been removed.
df = df.reset_index(drop = True)
df
# Out:
#                                            Event_Name  \
# 0                      Grace Jones' Meltdown festival
# 1                                 Art of Noise Reboot
# 2                      Grace Jones' Meltdown festival
# 3                                 Art of Noise Reboot
# 4                      Grace Jones' Meltdown festival
# 5   [CANCELLED] VØID: Venetian Snares & Big Lad vs...
# 6                                 Art of Noise Reboot
# 7    Throwback Thursdays at PI // Student Drink Deals
# 8   [RESCHEDULED] The Pickle Factory with Prosumer...
# 9                                Chancha Via Circuito
# 10               Session Victim: Every Friday in June
# 11  Fabio (Jungle Set) ft Jumping Jack Frost B2B B...
# 12                                         Gold Teeth
# 13                                             Antics
# 14                   Supa Dupa Fly x Trapeze Basement
# 15  [CANCELLED] Palms Trax b2b Young Marco & Kamma...
# 16                          Sankeys London Beach Rave
# 17  Byday Bynight - June's Summer Rooftop Party Br...
# 18                               Chancha Via Circuito
# 19                      Garagebox: 2020 Opening Party
# 20  [RESCHEDULED] Footwrk 005: Cosmic Disco with P...
# 21                                         UKG Brunch
# 22            London Boat Party with Free After Party
# 23  Shut The Front Door: Summer Solstice Day & Nig...
# 24                                          sub:Terra
# 25                   Clockwork Orange Clockstock 2020
# 26                                   One Out Festival
# 27      Foreverland Festival ∙ The Fantasy Fairground
# 28                                    The Get Up: TBC
# 29      Foreverland Festival ∙ The Fantasy Fairground
#
#                          Venue        Event_Date Number_of_Attendees
# 0             Southbank Centre  Mon, 15 Jun 2020                  30
# 1                The Jazz Cafe  Tue, 16 Jun 2020                   7
# 2             Southbank Centre  Tue, 16 Jun 2020                  30
# 3                The Jazz Cafe  Wed, 17 Jun 2020                   7
# 4             Southbank Centre  Wed, 17 Jun 2020                  30
# 5                       fabric  Wed, 17 Jun 2020                  24
# 6                The Jazz Cafe  Thu, 18 Jun 2020                   1
# 7         Piccadilly Institute  Thu, 18 Jun 2020                   0
# 8           The Pickle Factory  Fri, 19 Jun 2020                  75
# 9                The Jazz Cafe  Fri, 19 Jun 2020                  13
# 10               The Jazz Cafe  Fri, 19 Jun 2020                  13
# 11             Camden Assembly  Fri, 19 Jun 2020                   2
# 12                Brixton Jamm  Fri, 19 Jun 2020                   1
# 13                 Fest Camden  Fri, 19 Jun 2020                   1
# 14             Trapeze Basemen  Fri, 19 Jun 2020                   1
# 15                        XOYO  Fri, 19 Jun 2020                  63
# 16                  Studio 338  Sat, 20 Jun 2020                 199
# 17         The Prince of Wales  Sat, 20 Jun 2020                  63
# 18               The Jazz Cafe  Sat, 20 Jun 2020                  13
# 19                TBA - London  Sat, 20 Jun 2020                   7
# 20            Simulacra Studio  Sat, 20 Jun 2020                   6
# 21                TBA - London  Sat, 20 Jun 2020                   2
# 22                  Crown Pier  Sat, 20 Jun 2020                   2
# 23                Brixton Jamm  Sat, 20 Jun 2020                   1
# 24         Forest Road Brewery  Sat, 20 Jun 2020                   0
# 25  Chelmsford City Racecourse  Sat, 20 Jun 2020                  21
# 26     Apps Court Farm, Surrey  Sat, 20 Jun 2020                   0
# 27           Dreamland Margate  Sat, 20 Jun 2020                   0
# 28             Fire & Lightbox  Sat, 20 Jun 2020                   0
# 29           Dreamland Margate  Sun, 21 Jun 2020                   4

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page

# %%
# put together everything from before

def scrape_events(events_page_url):
    #Your code here
    page = requests.get(events_page_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # set up the container
    container = soup.find(id = 'items')
    
    # set up each row of the container, we will be iterating over each row of the container
    rows = container.findAll('li') # each row is identifiable by its tag 'li'
    
    # traverse the container; searching by h1 heading should narrow things down
    eventdata = container.findAll('h1', class_ ='event-title') # eventdata contains both name and venue
    
    # write a loop that iterates through the container for a list of names that will be used in the dataframe (final_name_list)
    final_name_list = [ ]

    #set up a list that contains the list of names
    #this list will be used by the for loop to populate the final_name_list 
    #ONLY where an event-title exists.
    name_list = [ ]

    # this loop is used to populate a list of event names for use in name_list
    for n in range(len(eventdata)):
        name = eventdata[n].find('a').text
        name_list.append(name)

    # this loop is used to check if there is an event name in a row, if not, return NaN
    # if there is an event name, it takes the actual name of the event from name_list and uses it to populate final_name_list
    # final_name_list goes into final dataframe

    name_list_counter = 0

    for n in range(len(rows)):
    
        if rows[n].find(class_ = 'event-title') == None:
            final_name_list.append('NaN')
            
        else:
            
            final_name_list.append(name_list[name_list_counter])
            name_list_counter += 1
   
    # set up a list of venues actually found in the container that will be used to populate final_venue_list
    venue_list = [ ]

    # set up an empty list of final_venue_list which will be used to construct the dataframe
    final_venue_list = [ ]

    # this loop is used to populate the event names actually found in the container that will, in turn, be used to
    # populate the final_venue_list
    for v in range(len(eventdata)):
        venue = eventdata[v].find('span').text.strip('at ')
        venue_list.append(venue)

    # this loop is used to populate the final_venue_list used in the dataframe, it will search each row of the container
    # where it does not find a venue name in a row, it will return NaN and populate final_venue_list accordingly
    # where it does find a venue name, it will take a name from the venue_list and populate final_venue_list accordingly.

    venue_list_counter = 0

    for v in range(len(rows)):
    
        if rows[v].find(class_ = 'event-title') == None:
            final_venue_list.append('NaN')
        else:
            final_venue_list.append(venue_list[venue_list_counter])
            venue_list_counter += 1 
    
    # write a loop that iterates through the container for the date of the event to generate a list
    # NOTE: certain dates have more events than others
    final_date_list = [ ]

    for d in range(len(rows)):
        if rows[d].find(class_ = 'eventDate date') == None:
            final_date_list.append(date)
        else:
            date = rows[d].find('a').text.strip(' /')
            final_date_list.append(date) 
    
    #set up an empty list, populating with number of attendees specified by the page.
    attend_list = [ ]

    #set up a final_attend_list to be used to construct the dataframe, this is populated with
    #the figures from attend_list where available and populated with NaN if not available.
    final_attend_list = [ ]
    
    # This narrows down into listings that do have attendees
    attend = container.findAll('p', class_ = 'attending')

    # this loop populates attend_list and creates a list of number of attendees where they have been specified
    for a in range(len(attend)):
        a_num = int(attend[a].text.strip('Attending '))
        attend_list.append(a_num)

    # this loop populates the final_attend_list such with numbers from attend_list where available, otherwise for listings
    # that do not specify any number of attendees, NaN is returned.

    attend_list_counter = 0

    for a in range(len(rows)):
        
        if rows[a].find(class_ = 'attending') == None:
            final_attend_list.append(0)
            
        else:
            final_attend_list.append(attend_list[attend_list_counter])
            attend_list_counter +=1
    
    final_lists = [final_name_list, final_venue_list, final_date_list, final_attend_list]
    
    # construct the dataframe
    df = pd.DataFrame(final_lists).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]

    #columns where the Event Name is NaN can be removed.
    df = df.loc[df['Event_Name'] != 'NaN']

    # this resets the index and drops the old index which doesn't work anymore now that the NaNs have been removed.
    df = df.reset_index(drop = True)
    
    return df

# %%
scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                            Event_Name  \
# 0                                Music Sans Frontiers
# 1                          Shy b2b Cat All Night Long
# 2                               Yves Tumor & Its Band
# 3                                            Despacio
# 4                                Techno RE-Imagine:06
# 5                   [POSTPONED] - Dispatch Recordings
# 6    Human Traffic Live, Opening Night with Pete Tong
# 7                         Katermukke Showcase: London
# 8         The Fleetwood Mac Summer Rooftop Party 2020
# 9                                All Points East 2020
# 10         Sonance: The Second Birthday (Free Techno)
# 11                                             Antics
# 12                                    The Delta House
# 13                           The Gallery: Bassjackers
# 14              1001 Afternoons with Wycliffe Mundopa
# 15  [CANCELLED] Palms Trax b2b Hunee (All Night Lo...
# 16  [CANCELLED] Superstition X Never Sleep with Ga...
# 17       [CANCELLED] Fridays at EGG: Nervo and Guests
# 18        [CANCELLED] Interior Motion with Adi Toohey
# 19              [POSTPONED] Pure Bacchanal - Shutdown
# 20            The Cause: 2nd Birthday XXX Block Party
# 21                  Volt presents: Swarm Intelligence
# 22  Critical Sound Summer Sonics BBQ // London - P...
# 23  Return Bank Holiday Day & Night - Half Baked &...
# 24                       Lets Love Life Festival 2020
# 25                        Night Tales: Dyed Soundorom
# 26                Drum & Bass BBQ - Day & Night Party
# 27             Metropolis Does Disco - Every Saturday
# 28                   Mantra: Every Saturday at Phonox
# 29                       VIP London 3rd Birthday Bash
# 30                                          East Ends
# 31                               All Points East 2020
# 32              Human Traffic Live & Clockwork Orange
# 33                                            untamed
# 34                                           Despacio
# 35             Cafe Mambo Classics @WE Are Fstvl 2020
# 36              1001 Afternoons with Wycliffe Mundopa
# 37  Music Unity For Mental Health presents Emotion...
# 38                [CANCELLED] Boiler Room TEN: London
# 39  [CANCELLED] EGG LDN Pres: Joyhauser, Timmo, An...
# 40      [CANCELLED] Ambrose Akinmusire [Venue Closed]
# 41  [CANCELLED] Soul City: Disco, House & Soul - B...
# 42                         Brunch Electronik - London
# 43         The Rampage Sound Bank Holiday Sunday Rave
# 44   Bank Holiday Sunday: Sandy Rivera [Venue Closed]
# 45  Norman Jay & Melvo Baptiste...Up On The Roof +...
# 46                   2 Da Empire 2020 ( 2nd Edition )
# 47           M.V Jewel of London  Sun, 24 May 2020                   0
# 48            The Pickle Factory  Sun, 24 May 2020                   0
# 49                      The Scal  Sun, 24 May 2020                   0
# 50                     Club Rein  Sun, 24 May 2020                   0
# 51                 Victoria Park  Sun, 24 May 2020                   0
# 52                    Printworks  Sun, 24 May 2020                   0
# 53                    Printworks  Sun, 24 May 2020                   0
# 54         Damyns Hall Aerodrome  Sun, 24 May 2020                   0
# 55  Kristin Hjellegjerde Gallery  Sun, 24 May 2020                   0
# 56          The Victoria Dalston  Sun, 24 May 2020                   0

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# find the section in the soup where the previous and next buttons can be found
next_container = soup.find('div', class_ = 'page-items content sub clearfix')
next_container
# Out:
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-08">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/uk/london/week/2020-06-22">Next </a>
# </li>
# </ul>
# </div>

# %%
# this will list links to both the previous AND the next buttons
buttons = next_container.findAll('a', href=True)

# the next button is index number 1 in the buttons list, specifying ['href'] like that should get the url for the next button
next = buttons[1]['href']
next
# Out:
# '/events/uk/london/week/2020-06-22'

# %%
# Now, a bit of string manipulation to join everything up, use a literal to complete the url and ensure it is a string
# This is what the full url looks like:
# https://www.residentadvisor.net/events/uk/london/week/2020-06-22

next_url = str(print('https://www.residentadvisor.net{}'.format(next)))
# Out:
# https://www.residentadvisor.net/events/uk/london/week/2020-06-22

# %%
# putting the above together

def next_page(url):
    #set up the page and the soup
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # find the section in the soup where the previous and next buttons can be found
    next_container = soup.find('div', class_ = 'page-items content sub clearfix')
    
    # this will list links to both the previous AND the next buttons
    buttons = next_container.findAll('a', href=True)

    # the next button is index number 1 in the buttons list, specifying ['href'] like that should get the url for the next button
    next = buttons[1]['href']
    
    # Now, a bit of string manipulation to join everything up, use a literal to complete the url and ensure it is a string
    # This is what the full url looks like: https://www.residentadvisor.net/events/uk/london/week/2020-06-22

    next_page_url = 'https://www.residentadvisor.net{}'.format(next)
    
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
# construct an initial dataframe of the initial page where scraping begins
start_url = 'https://www.residentadvisor.net/events'
df_large = scrape_events(start_url)

# get the next url; there will definitely be need of another url, we aren't going to get 1000 listings in 1 page....

new_url = next_page(start_url)

# scrape the next page and add the dataframe constructed thereby to the initial dataframe
# remember to test the length of the dataframe 
# keep running the loop to scrape the following page until the length of the dataframe = 500

df_length = len(df_large)

while df_length < 400:
    next_df = scrape_events(new_url)
    df_large = pd.concat([df_large, next_df])
    df_length = len(df_large)
    if df_length >= 400:
        break
    new_url = next_page(new_url)

# tidy up the index
df_large = df_large.reset_index(drop = True)

# %%
df_large = df_large.sort_values(by = ['Number_of_Attendees', 'Event_Name'], ascending = [False, True], axis=0)
# Out:
#                                             Event_Name  \
# 151         [CANCELLED] Cross The Tracks Festival 2020
# 296                    LoveJuice Block Party at Site 5
# 375                                Waterworks Festival
# 274                                     Field Day 2020
# 297  [RESCHEDULED] E1 & Labyrinth present: Sasha, J...
# 220  [RESCHEDULED] Symmetry with Break, Skeptical, ...
# 348                                         Bicep Live
# 128                 Nuestra Casa // Shockers Bday Bash
# 211                                   One Out Festival
# 99   Origins x Night Tales: John Talabot, Armând & ...
# 257                              Plastician Does Disco
# 242                         Pony - Old Skool RnB Party
# 327                         Pony - Old Skool RnB Party
# 404                         Pony - Old Skool RnB Party
# 146                                         Pour IT UP
# 286                 Ron Basejam (Futureboogie Records)
# 47                  Shrumba on the Thames (Boat Party)
# 103    Sicko Mode Shoreditch - Shoreditch's No 1 Party
# 405    Sicko Mode Shoreditch - Shoreditch's No 1 Party
# 129                So Lucky vs Dialect Full Moon Party
# 48   Soul In Motion with Very Special Guests, Baile...
# 412                     South East Dance Festival 2020
# 403                               South West Four 2020
# 411                               South West Four 2020
# 241        Summer Boat Party with a Secret After Party
# 340           The Big Disco - Summer Day & Night Party
# 83                           The Gallery: Paul van Dyk
# 213                                    The Get Up: TBC
# 162                      The Summer Funk, Soul & Disco
# 115   Throwback Thursdays at PI // Student Drink Deals
# 156   Throwback Thursdays at PI // Student Drink Deals
# 192   Throwback Thursdays at PI // Student Drink Deals
# 219   Throwback Thursdays at PI // Student Drink Deals
# 264   Throwback Thursdays at PI // Student Drink Deals
# 293   Throwback Thursdays at PI // Student Drink Deals
# 309   Throwback Thursdays at PI // Student Drink Deals
# 330   Throwback Thursdays at PI // Student Drink Deals
# 142                                         UKG Brunch
# 285                             UKG Brunch On the Boat
# 29                        VIP London 3rd Birthday Bash
# 144                                 Vocal House Brunch
# 326                              We Are One - Saturday
# 94                    Wonderlove Cruise- Reggae Cruise
# 56             [CANCELLED] 117 May Bank Holiday Sunday
# 85                              [CANCELLED] Allegiance
# 40       [CANCELLED] Ambrose Akinmusire [Venue Closed]
# 38                 [CANCELLED] Boiler Room TEN: London
# 39   [CANCELLED] EGG LDN Pres: Joyhauser, Timmo, An...
# 17        [CANCELLED] Fridays at EGG: Nervo and Guests
# 168                      [CANCELLED] Future Retro #001
# 18         [CANCELLED] Interior Motion with Adi Toohey
# 147  [CANCELLED] MATERIALS: Open Air Terrace + Ware...
# 106                     [CANCELLED] Møtif Launch Party
# 169        [CANCELLED] Palms Trax & Beautiful Swimmers
# 130             [CANCELLED] Palms Trax & Special Guest
# 230  [CANCELLED] Palms Trax (All Night Long) - Clos...
# 84   [CANCELLED] Palms Trax + Lena Willikens & Vlad...
# 15   [CANCELLED] Palms Trax b2b Hunee (All Night Lo...
# 148  [CANCELLED] Resonate LDN Pres Reconnect After ...
# 41   [CANCELLED] Soul City: Disco, House & Soul - B...
# 108  [CANCELLED] Soul City: Disco, House & Soul Eve...
# 107          [CANCELLED] Superstition X Circle Of Live
# 16   [CANCELLED] Superstition X Never Sleep with Ga...
# 307  [POSTPONED] DWF - Sailing with Friends Boat Party
# 19               [POSTPONED] Pure Bacchanal - Shutdown
# 105  [POSTPONED] Secretsundaze Daytime Summer Block...
# 328  [RESCHEDULED] Black88 - Boxia (Drumcode) - Tec...
# 363  [RESCHEDULED] Metafloor 2nd Birthday - Line Up...
# 181          [RESCHEDULED] Secret Garden Rave - London
# 329               [Rescheduled] Origins: tINI & Armând
# 328                                 Werkhaus  Sat, 25 Jul 2020
# 363                             Basing House  Sat, 08 Aug 2020
# 181                           The Steel Yard  Sat, 13 Jun 2020
# 329                              Night Tales  Sat, 25 Jul 2020
# 325                              93 Feet Eas  Sat, 25 Jul 2020
# 209                      Forest Road Brewery  Sat, 20 Jun 2020
# 33                           Secret Location  Sat, 23 May 2020
#
#     Number_of_Attendees
# 151                4339
# 296                1489
# 375                1385
# 274                1213
# 297                 578
# 220                 347
# 348                 316
# 265                 280
# 231                 271
# 374                 247
# 131                 239
# 310                 228
# 384                 218
# 335                 211
# 251                 202
# 201                 199
# 385                 190
# 163                 187
# 176                 187
# 183                 187
# 132                 181
# 314                 173
# 344                 165
# 393                 160
# 157                 158
# 232                 148
# 252                 145
# 358                 144
# 275                 141
# 364                 137
# 349                 135
# 170                 129
# 367                 127
# 394                 125
# 345                 124
# 368                 114
# 20                  110
# 42                  104
# 376                 100
# 5                    99
# 9                    96
# 253                  93
# 315                  93
# 113                  92
# 71                   88
# 395                  88
# 158                  76
# 193                  75
# 291                  68
# 243                  67
# 316                  66
# 202                  63
# 200                  63
# 58                   62
# 116                  62
# 336                  59
# 276                  59
# 258                  58
# 43                   52
# 346                  51
# 221                  51
# 245                  50
# 222                  49
# 44                   47
# 383                  44
# 117                  41
# 118                  41
# 133                  39
# 45                   37
# 171                  34
# 182                  34
# 304                  31
# 277                  31
# 396                  30
# 164                  30
# 177                  30
# 184                  30
# 185                  30
# 187                  30
# 189                  30
# 353                  28
# 406                  28
# 21                   27
# 317                  26
# 119                  26
# 2                    26
# 331                  26
# 292                  25
# 6                    24
# 190                  24
# 266                  24
# 134                  23
# 278                  22
# 210                  21
# 267                  20
# 22                   19
# 3                    17
# 172                  17
# 23                   17
# 263                  16
# 270                  16
# 279                  16
# 247                  16
# 223                  14
# 365                  14
# 194                  13
# 203                  13
# 226                  13
# 178                  13
# 195                  13
# 318                  13
# 10                   13
# 233                  13
# 159                  12
# 218                  12
# 72                   11
# 311                  11
# 377                  10
# 407                  10
# 294                  10
# 234                   9
# 124                   9
# 280                   9
# 73                    9
# 298                   9
# 354                   9
# 386                   9
# 387                   8
# 7                     8
# 299                   8
# 135                   8
# 408                   8
# 397                   8
# 359                   7
# 238                   7
# 186                   7
# 188                   7
# 259                   7
# 204                   7
# 295                   7
# 300                   7
# 399                   6
# 260                   6
# 86                    6
# 398                   6
# 332                   6
# 205                   6
# 268                   5
# 153                   5
# 87                    5
# 254                   5
# 112                   5
# 160                   5
# 24                    5
# 400                   5
# 173                   5
# 347                   5
# 388                   4
# 214                   4
# 114                   4
# 25                    4
# 74                    4
# 235                   4
# 244                   4
# 369                   4
# 57                    3
# 281                   3
# 350                   3
# 378                   3
# 319                   3
# 120                   3
# 136                   3
# 370                   3
# 110                   3
# 111                   3
# 65                    3
# 68                    3
# 154                   3
# 165                   3
# 301                   3
# 320                   3
# 282                   3
# 337                   3
# 355                   3
# 312                   3
# 70                    3
# 215                   2
# 216                   2
# 78                    2
# 227                   2
# 313                   2
# 351                   2
